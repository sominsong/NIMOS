# %% [markdown]
# ### ftrace parsing

# %%
import os
def split_threads(img, filename):
    threads = set()
    # img_filename.txt
    with open(f"/opt/output/tracing/{img}_{filename}.txt","r") as rf:
        # collect thread id (pids)
        for line in rf.readlines():
            if "#" in line:
                continue
            else:
                pid = line.strip().split()[0].replace("<...>-","")
                threads.add(pid)
        
        # split syscall tracing per pid
        for pid in threads:
            trace_readlines = subprocess.check_output(f'grep "{pid}" /opt/output/tracing/{img}_{filename}.txt', shell=True).decode().split("\n")
            print(f"{img}_{filename}-{pid}.txt")
            with open(f"../data/split/{img}_{filename}-{pid}.txt","w") as wf:
                for line in trace_readlines:              
                    wf.write(line+"\n")

# %% [markdown]
# ### strace-container parsing

# %%
def split_threads_for_strace(img, filename):
    threads = set()
    # img_filename.txt
    with open(f"/opt/output/tracing/{img}_{filename}.txt","r") as rf:
        # collect thread id (pids)
        for line in rf.readlines():
            pid = line.strip().split()[0]
            threads.add(pid)
        
        # split syscall tracing per pid
        for pid in threads:
            trace_readlines = subprocess.check_output(f'grep "{pid}" /opt/output/tracing/{img}_{filename}.txt', shell=True).decode().split("\n")
            print(f"{img}_{filename}-{pid}.txt")
            with open(f"../data/split/{img}_{filename}-{pid}.txt","w") as wf:
                for line in trace_readlines:
                    wf.write(line+"\n")

# %%
import subprocess

# imgnames = ["mongodb", "mysql", "mariadb"]
# nignx/node - single
# imgnames = ["redis", "tomcat", "httpd"]
imgnames = ["gcc", "openjdk", "qalc", "lowriter"]


for img in imgnames:
    cmd = f"find /opt/output/tracing -type f -name '{img}_*.txt'"
    files=subprocess.check_output(cmd, shell=True).decode().split('\n')
    files.pop(-1)
    tmp_files = list()
    for file in files:
        if "/old/" in file:
            continue
        else:
            tmp_files.append(file)
    print(f"{img} output file #: {len(tmp_files)}")
    
    for file in tmp_files:
        filename = file.replace(f"/opt/output/tracing/{img}_","").replace(".txt","")
#         split_threads(img, filename)
        split_threads_for_strace(img, filename)
# Out:
# gcc output file #: 2
# gcc_strace2-1386532.txt
# gcc_strace2-1386531.txt
# gcc_strace2-1386535.txt
# gcc_strace2-1386533.txt
# gcc_strace2-1386534.txt
# gcc_strace2-1386420.txt
# gcc_strace2-1386374.txt
# gcc_strace1-1382990.txt
# gcc_strace1-1383104.txt
# gcc_strace1-1383103.txt
# gcc_strace1-1383106.txt
# gcc_strace1-1382943.txt
# gcc_strace1-1383107.txt
# gcc_strace1-1383105.txt
# openjdk output file #: 2
# openjdk_strace2-1446335.txt
# openjdk_strace2-1446328.txt
# openjdk_strace2-1446291.txt
# openjdk_strace2-1446299.txt
# openjdk_strace2-1446324.txt
# openjdk_strace2-1446284.txt
# openjdk_strace2-1446318.txt
# openjdk_strace2-1446301.txt
# openjdk_strace2-1446298.txt
# openjdk_strace2-1446292.txt
# openjdk_strace2-1446212.txt
# openjdk_strace2-1446305.txt
# openjdk_strace2-1446304.txt
# openjdk_strace2-1446287.txt
# openjdk_strace2-1446289.txt
# openjdk_strace2-1446260.txt
# openjdk_strace2-1446285.txt
# openjdk_strace2-1446303.txt
# openjdk_strace2-1446323.txt
# openjdk_strace2-1446326.txt
# openjdk_strace2-1446296.txt
# openjdk_strace2-1446300.txt
# openjdk_strace2-1446319.txt
# openjdk_strace2-1446288.txt
# openjdk_strace2-1446290.txt
# openjdk_strace2-1446327.txt
# openjdk_strace2-1446317.txt
# openjdk_strace2-1446294.txt
# openjdk_strace2-1446286.txt
# openjdk_strace2-1446295.txt
# openjdk_strace2-1446297.txt
# openjdk_strace2-1446325.txt
# openjdk_strace2-1446302.txt
# openjdk_strace2-1446293.txt
# openjdk_strace1-1442850.txt
# openjdk_strace1-1442865.txt
# openjdk_strace1-1442849.txt
# openjdk_strace1-1442841.txt
# openjdk_strace1-1442862.txt
# openjdk_strace1-1442863.txt
# openjdk_strace1-1442854.txt
# openjdk_strace1-1442848.txt
# openjdk_strace1-1442843.txt
# openjdk_strace1-1442851.txt
# openjdk_strace1-1442846.txt
# openjdk_strace1-1442856.txt
# openjdk_strace1-1442867.txt
# openjdk_strace1-1442860.txt
# openjdk_strace1-1442852.txt
# openjdk_strace1-1442868.txt
# openjdk_strace1-1442762.txt
# openjdk_strace1-1442840.txt
# openjdk_strace1-1442837.txt
# openjdk_strace1-1442857.txt
# openjdk_strace1-1442838.txt
# openjdk_strace1-1442866.txt
# openjdk_strace1-1442853.txt
# openjdk_strace1-1442855.txt
# openjdk_strace1-1442864.txt
# openjdk_strace1-1442869.txt
# openjdk_strace1-1442842.txt
# openjdk_strace1-1442813.txt
# openjdk_strace1-1442839.txt
# openjdk_strace1-1442844.txt
# openjdk_strace1-1442835.txt
# openjdk_strace1-1442847.txt
# openjdk_strace1-1442836.txt
# openjdk_strace1-1442861.txt
# openjdk_strace1-1442845.txt
# qalc output file #: 2
# qalc_vector-2121167.txt
# qalc_vector-2121233.txt
# qalc_vector-2121231.txt
# qalc_vector-2121232.txt
# qalc_vector-2121234.txt
# qalc_matrix-2122147.txt
# qalc_matrix-2122144.txt
# qalc_matrix-2122073.txt
# qalc_matrix-2122146.txt
# lowriter output file #: 3
# lowriter_doctopdf-2058396.txt
# lowriter_doctopdf-2058367.txt
# lowriter_doctopdf-2058381.txt
# lowriter_doctopdf-2058375.txt
# lowriter_doctopdf-2058380.txt
# lowriter_doctopdf-2058352.txt
# lowriter_doctopdf-2058376.txt
# lowriter_doctopdf-2058397.txt
# lowriter_doctopdf-2058402.txt
# lowriter_doctopdf-2058288.txt
# lowriter_doctopdf-2058369.txt
# lowriter_doctopdf-2058379.txt
# lowriter_doctopdf-2058372.txt
# lowriter_doctopdf-2058360.txt
# lowriter_doctopdf-2058394.txt
# lowriter_doctopdf-2058378.txt
# lowriter_doctopdf-2058366.txt
# lowriter_doctopdf-2058386.txt
# lowriter_doctopdf-2058387.txt
# lowriter_doctopdf-2058395.txt
# lowriter_doctopdf-2058364.txt
# lowriter_doctopdf-2058398.txt
# lowriter_doctopdf-2058370.txt
# lowriter_doctopdf-2058362.txt
# lowriter_doctopdf-2058388.txt
# lowriter_doctopdf-2058382.txt
# lowriter_doctopdf-2058400.txt
# lowriter_doctopdf-2058405.txt
# lowriter_doctopdf-2058401.txt
# lowriter_doctopdf-2058371.txt
# lowriter_doctopdf-2058383.txt
# lowriter_doctopdf-2058374.txt
# lowriter_doctopdf-2058373.txt
# lowriter_doctopdf-2058385.txt
# lowriter_doctopdf-2058384.txt
# lowriter_doctopdf-2058368.txt
# lowriter_doctopdf-2058377.txt
# lowriter_doctopdf-2058399.txt
# lowriter_doctopdf-2058365.txt
# lowriter_encodeUTF8-2059769.txt
# lowriter_encodeUTF8-2059766.txt
# lowriter_encodeUTF8-2059770.txt
# lowriter_encodeUTF8-2059724.txt
# lowriter_encodeUTF8-2059777.txt
# lowriter_encodeUTF8-2059760.txt
# lowriter_encodeUTF8-2059773.txt
# lowriter_encodeUTF8-2059759.txt
# lowriter_encodeUTF8-2059740.txt
# lowriter_encodeUTF8-2059778.txt
# lowriter_encodeUTF8-2059751.txt
# lowriter_encodeUTF8-2059748.txt
# lowriter_encodeUTF8-2059771.txt
# lowriter_encodeUTF8-2059779.txt
# lowriter_encodeUTF8-2059765.txt
# lowriter_encodeUTF8-2059746.txt
# lowriter_encodeUTF8-2059738.txt
# lowriter_encodeUTF8-2059749.txt
# lowriter_encodeUTF8-2059758.txt
# lowriter_encodeUTF8-2059745.txt
# lowriter_encodeUTF8-2059660.txt
# lowriter_encodeUTF8-2059772.txt
# lowriter_encodeUTF8-2059750.txt
# lowriter_encodeUTF8-2059741.txt
# lowriter_encodeUTF8-2059734.txt
# lowriter_encodeUTF8-2059742.txt
# lowriter_encodeUTF8-2059756.txt
# lowriter_encodeUTF8-2059757.txt
# lowriter_encodeUTF8-2059780.txt
# lowriter_encodeUTF8-2059767.txt
# lowriter_encodeUTF8-2059744.txt
# lowriter_encodeUTF8-2059747.txt
# lowriter_encodeUTF8-2059774.txt
# lowriter_encodeUTF8-2059736.txt
# lowriter_encodeUTF8-2059743.txt
# lowriter_encodeUTF8-2059752.txt
# lowriter_odttopdf-2059066.txt
# lowriter_odttopdf-2058975.txt
# lowriter_odttopdf-2059065.txt
# lowriter_odttopdf-2059074.txt
# lowriter_odttopdf-2059090.txt
# lowriter_odttopdf-2059060.txt
# lowriter_odttopdf-2059056.txt
# lowriter_odttopdf-2059092.txt
# lowriter_odttopdf-2059054.txt
# lowriter_odttopdf-2059095.txt
# lowriter_odttopdf-2059086.txt
# lowriter_odttopdf-2059071.txt
# lowriter_odttopdf-2059063.txt
# lowriter_odttopdf-2059059.txt
# lowriter_odttopdf-2059084.txt
# lowriter_odttopdf-2059085.txt
# lowriter_odttopdf-2059078.txt
# lowriter_odttopdf-2059061.txt
# lowriter_odttopdf-2059072.txt
# lowriter_odttopdf-2059088.txt
# lowriter_odttopdf-2059057.txt
# lowriter_odttopdf-2059079.txt
# lowriter_odttopdf-2059089.txt
# lowriter_odttopdf-2059062.txt
# lowriter_odttopdf-2059070.txt
# lowriter_odttopdf-2059073.txt
# lowriter_odttopdf-2059055.txt
# lowriter_odttopdf-2059069.txt
# lowriter_odttopdf-2059087.txt
# lowriter_odttopdf-2059067.txt
# lowriter_odttopdf-2059077.txt
# lowriter_odttopdf-2059076.txt
# lowriter_odttopdf-2059082.txt
# lowriter_odttopdf-2059081.txt
# lowriter_odttopdf-2059046.txt
# lowriter_odttopdf-2059080.txt
# lowriter_odttopdf-2059075.txt
# lowriter_odttopdf-2059064.txt
# lowriter_odttopdf-2059058.txt
# lowriter_odttopdf-2059068.txt
# lowriter_odttopdf-2059091.txt

# %%
# hyper-seccomp/app/data/split/{img}_{op}_{pid}.txt 파일 /opt/output/tracing/ 하위로 옮기기 (bashs로)
